# %% [markdown]
# ## Mandatory Assignment: Collect data
#
# 1) Collect data on Age, Height and MobileOS from a sample of 5 participants.
#
# 2) Make a Jupyter notebook in your folder in the course project on UCloud (you can copy /save an earlier notebook as template and remove non-relevant cells)
#
# https://cloud.sdu.dk/app/projects/invite/28d3c7fc-d69f-4f78-960d-4b9e0c2e5163
#
# 3) Enter the data collected from your sample in the new Jupyter notebook.
#
# 4) Convert into a data frame and use in-built functions to get:
#
#  * the size of the data frame
#
#  * description of data frame
#
# 5) ANSWER: What type of sampling/recruitment method did you use?
#
# 6) ANSWER: What could be potential bias in your sample?
#
# 7) Save and upload to your Github. Submit the link to your Github here by the deadline. Make your best try also if you are unsure about how to solve something.

# %% [markdown]
# ### 1

# %%
# done in file datahomework1.csv

# %% [markdown]
# ### 2

# %%
# done made this file here homework1.ipynb

# %% [markdown]
# ### 3

# %%
import pandas as pd

My_data = pd.read_csv('datahomework1.csv')
#print(My_data)

# %% [markdown]
# ### 4

# %%
My_data.size
# Out:
# 20

# %%
My_data.describe
# Out:
# <bound method NDFrame.describe of                     Timestamp  How old are you? How tall are you?  \
# 0  2026/02/26 10:38:29 am CET                32            193 cm
# 1  2026/02/26 10:39:23 am CET                27               192
# 2  2026/02/26 10:39:47 am CET                21              190
# 3  2026/02/26 10:41:09 am CET                15               200
# 4  2026/02/26 10:42:20 am CET                21               183
#
#   What operating system does your phone use?
# 0                                    Android
# 1                                        IOS
# 2                                        IOS
# 3                                        IOS
# 4                                        IOS  >

# %% [markdown]
# ### 5

# %%
# first come first wrote down from project groupe

# %% [markdown]
# ### 6

# %%
# having all univeristy studends that work together

# %% [markdown]
# ### 7

# %%
# downloading and saving to lokal git
